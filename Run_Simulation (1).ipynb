# %%
import numpy as np
from chain_ucb_simulation import run_chain_simulation
from format_results import format_results

# %%
## Short Term: 250, 500

# %% [markdown]
# ### Early Stage (Warm start 50, T = 250)

# %%
result_50_250 = run_chain_simulation(
    K=4,
    delta_min=0.003,
    delta_max=0.020,
    mu2_range=(0.01, 0.10),
    offset_range=(-0.005, 0.005),
    eps=0.002,
    T=250,
    K_rep=1000,
    M0=50,
    C=2.0,
    rng=np.random.default_rng(2026),
    verbose=True,
)

format_results(result_50_250)
# Out:
# Replication 0/1000
# Replication 100/1000
# Replication 200/1000
# Replication 300/1000
# Replication 400/1000
# Replication 500/1000
# Replication 600/1000
# Replication 700/1000
# Replication 800/1000
# Replication 900/1000
# <style type="text/css">
# #T_ce41a caption {
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 6px;
# }
# #T_ce41a th {
#   background-color: #f5f5f5;
#   border: 1px solid #d0d0d0;
#   padding: 6px 12px;
#   text-align: center;
# }
# #T_ce41a td {
#   border: 1px solid #d0d0d0;
#   padding: 5px 12px;
#   text-align: center;
# }
# #T_ce41a tr:nth-child(even) {
#   background-color: #fafafa;
# }
# </style>
# <table id="T_ce41a">
#   <caption><b>Regret</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce41a_level0_col0" class="col_heading level0 col0" >Mean(base)</th>
#       <th id="T_ce41a_level0_col1" class="col_heading level0 col1" >Mean(share)</th>
# ...

# %%
result_50_500 = run_chain_simulation(
    K=4,
    delta_min=0.003,
    delta_max=0.020,
    mu2_range=(0.01, 0.10),
    offset_range=(-0.005, 0.005),
    eps=0.002,
    T=500,
    K_rep=1000,
    M0=50,
    C=2.0,
    rng=np.random.default_rng(2026),
    verbose=True,
)
format_results(result_50_500)
# Out:
# Replication 0/1000
# Replication 100/1000
# Replication 200/1000
# Replication 300/1000
# Replication 400/1000
# Replication 500/1000
# Replication 600/1000
# Replication 700/1000
# Replication 800/1000
# Replication 900/1000
# <style type="text/css">
# #T_35ba9 caption {
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 6px;
# }
# #T_35ba9 th {
#   background-color: #f5f5f5;
#   border: 1px solid #d0d0d0;
#   padding: 6px 12px;
#   text-align: center;
# }
# #T_35ba9 td {
#   border: 1px solid #d0d0d0;
#   padding: 5px 12px;
#   text-align: center;
# }
# #T_35ba9 tr:nth-child(even) {
#   background-color: #fafafa;
# }
# </style>
# <table id="T_35ba9">
#   <caption><b>Regret</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35ba9_level0_col0" class="col_heading level0 col0" >Mean(base)</th>
#       <th id="T_35ba9_level0_col1" class="col_heading level0 col1" >Mean(share)</th>
# ...

# %% [markdown]
# ## Long Term: 1k, 2.5k, 5k

# %%
result_50_1000 = run_chain_simulation(
    K=4,
    delta_min=0.003,
    delta_max=0.020,
    mu2_range=(0.01, 0.10),
    offset_range=(-0.005, 0.005),
    eps=0.002,
    T=1000,
    K_rep=1000,
    M0=50,
    C=2.0,
    rng=np.random.default_rng(2026),
    verbose=True,
)

format_results(result_50_1000)
# Out:
# Replication 0/1000
# Replication 100/1000
# Replication 200/1000
# Replication 300/1000
# Replication 400/1000
# Replication 500/1000
# Replication 600/1000
# Replication 700/1000
# Replication 800/1000
# Replication 900/1000
# <style type="text/css">
# #T_db236 caption {
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 6px;
# }
# #T_db236 th {
#   background-color: #f5f5f5;
#   border: 1px solid #d0d0d0;
#   padding: 6px 12px;
#   text-align: center;
# }
# #T_db236 td {
#   border: 1px solid #d0d0d0;
#   padding: 5px 12px;
#   text-align: center;
# }
# #T_db236 tr:nth-child(even) {
#   background-color: #fafafa;
# }
# </style>
# <table id="T_db236">
#   <caption><b>Regret</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db236_level0_col0" class="col_heading level0 col0" >Mean(base)</th>
#       <th id="T_db236_level0_col1" class="col_heading level0 col1" >Mean(share)</th>
# ...

# %%
result_50_2500 = run_chain_simulation(
    K=4,
    delta_min=0.003,
    delta_max=0.020,
    mu2_range=(0.01, 0.10),
    offset_range=(-0.005, 0.005),
    eps=0.002,
    T=2500,
    K_rep=1000,
    M0=50,
    C=2.0,
    rng=np.random.default_rng(2026),
    verbose=True,
)

format_results(result_50_2500)
# Out:
# Replication 0/1000
# Replication 100/1000
# Replication 200/1000
# Replication 300/1000
# Replication 400/1000
# Replication 500/1000
# Replication 600/1000
# Replication 700/1000
# Replication 800/1000
# Replication 900/1000
# <style type="text/css">
# #T_c250b caption {
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 6px;
# }
# #T_c250b th {
#   background-color: #f5f5f5;
#   border: 1px solid #d0d0d0;
#   padding: 6px 12px;
#   text-align: center;
# }
# #T_c250b td {
#   border: 1px solid #d0d0d0;
#   padding: 5px 12px;
#   text-align: center;
# }
# #T_c250b tr:nth-child(even) {
#   background-color: #fafafa;
# }
# </style>
# <table id="T_c250b">
#   <caption><b>Regret</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c250b_level0_col0" class="col_heading level0 col0" >Mean(base)</th>
#       <th id="T_c250b_level0_col1" class="col_heading level0 col1" >Mean(share)</th>
# ...

# %%
result_50_5000 = run_chain_simulation(
    K=4,
    delta_min=0.003,
    delta_max=0.020,
    mu2_range=(0.01, 0.10),
    offset_range=(-0.005, 0.005),
    eps=0.002,
    T=5000,
    K_rep=1000,
    M0=50,
    C=2.0,
    rng=np.random.default_rng(2026),
    verbose=True,
)

format_results(result_50_5000)
# Out:
# Replication 0/1000
# Replication 100/1000
# Replication 200/1000
# Replication 300/1000
# Replication 400/1000
# Replication 500/1000
# Replication 600/1000
# Replication 700/1000
# Replication 800/1000
# Replication 900/1000
# <style type="text/css">
# #T_e4440 caption {
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 6px;
# }
# #T_e4440 th {
#   background-color: #f5f5f5;
#   border: 1px solid #d0d0d0;
#   padding: 6px 12px;
#   text-align: center;
# }
# #T_e4440 td {
#   border: 1px solid #d0d0d0;
#   padding: 5px 12px;
#   text-align: center;
# }
# #T_e4440 tr:nth-child(even) {
#   background-color: #fafafa;
# }
# </style>
# <table id="T_e4440">
#   <caption><b>Regret</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4440_level0_col0" class="col_heading level0 col0" >Mean(base)</th>
#       <th id="T_e4440_level0_col1" class="col_heading level0 col1" >Mean(share)</th>
# ...
